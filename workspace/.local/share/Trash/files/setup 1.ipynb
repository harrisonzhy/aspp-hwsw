# %%
# %run pytorch2timeloop-converter/setup.py install
# Out:
# running install
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/setuptools/command/easy_install.py:501, in easy_install.check_site_dir(self)
#     500     os.unlink(testfile)
# --> 501 open(testfile, 'w').close()
#     502 os.unlink(testfile)
#
# PermissionError: [Errno 13] Permission denied: '/usr/local/lib/python3.8/dist-packages/test-easy-install-986.write-test'
#
# During handling of the above exception, another exception occurred:
#
# DistutilsError                            Traceback (most recent call last)
# File /usr/lib/python3.8/distutils/core.py:148, in setup(**attrs)
#     147 try:
# --> 148     dist.run_commands()
#     149 except KeyboardInterrupt:
#
# File /usr/lib/python3.8/distutils/dist.py:966, in Distribution.run_commands(self)
#     965 for cmd in self.commands:
# --> 966     self.run_command(cmd)
#
# ...
