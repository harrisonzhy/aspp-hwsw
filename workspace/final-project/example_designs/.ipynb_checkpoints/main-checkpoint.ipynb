# %%
# !find ../../../workspace -type d -name ".ipynb_checkpoints" -exec rm -rf {} +

# %%
# !python3 rename.py

# %%
# !python3 run_example_designs.py --architecture eyeriss_like --problem CONV/assp
# Out:
# Running mapper for target eyeriss_like in /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer3...
#
#
# Running mapper for target eyeriss_like in /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer4...
#
#
# Running mapper for target eyeriss_like in /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer5...
#
#
# Running mapper for target eyeriss_like in /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer2...
#
#
# Running mapper for target eyeriss_like in /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer1...
# input file: /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer4/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer3/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer2/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer5/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer1/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer4/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer3/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer5/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer2/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/eyeriss_like/outputs/assp_layer1/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 400
#   Factorization options along problem dimension M = 1
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 3
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
# Mapspace Dimension [IndexFactorization] Size: 1200
# Mapspace Dimension [LoopPermutation] Size: 4
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 300 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# [  0] Utilization = 0.01 | pJ/Compute =  140.398 | L6[WIO] N2 C25 - L5[IO] C20 - L4[] Q1 - L3[] Q1 C2Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.02 | pJ/Compute =  140.394 | L6[WIO] N2 C10 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C4Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  1] Utilization = 0.01 | pJ/Compute =  140.398 | L6[WIO] N2 C20 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C2Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  2] Utilization = 0.02 | pJ/Compute =  140.394 | L6[WIO] N2 C25 - L5[IO] C10 - L4[] Q1 - L3[] Q1 C4Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =  140.392 | L6[WIO] N2 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C8 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  140.385 | L6[WIO] N2 C25 - L5[IO] Q1 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  140.385 | L6[WIO] N2 C5 - L5[IO] C5 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  140.385 | L6[WIO] N2 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  141.840 | L6[WIO] C10 N2 - L5[IO] C10 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 400
#   Factorization options along problem dimension M = 1
#   Factorization options along problem dimension R = 5
#   Factorization options along problem dimension S = 5
#   Factorization options along problem dimension N = 3
#   Factorization options along problem dimension P = 2
#   Factorization options along problem dimension Q = 3
# Mapspace Dimension [IndexFactorization] Size: 180000
# Mapspace Dimension [LoopPermutation] Size: 518400
# Generate Accelergy ART (area reference table) to replace internal area model.
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 45000 Residue: 0
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Mapspace construction complete.
# Search configuration complete.
# [  3] Utilization = 0.05 | pJ/Compute =  110.910 | L6[WIO] C25 N2 - L5[IO] Q1 - L4[] Q1 - L3[] Q1 C8Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 400
#   Factorization options along problem dimension M = 1
#   Factorization options along problem dimension R = 5
#   Factorization options along problem dimension S = 5
#   Factorization options along problem dimension N = 3
#   Factorization options along problem dimension P = 5
#   Factorization options along problem dimension Q = 13
# Mapspace Dimension [IndexFactorization] Size: 1950000
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 487500 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# Initializing Index Factorization subspace.
# [  1] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C10 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C2 - L5[IO] C25 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C25 - L5[IO] C2 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 400
#   Factorization options along problem dimension M = 1
#   Factorization options along problem dimension R = 5
#   Factorization options along problem dimension S = 5
#   Factorization options along problem dimension N = 3
#   Factorization options along problem dimension P = 2
#   Factorization options along problem dimension Q = 3
# Mapspace Dimension [IndexFactorization] Size: 180000
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 45000 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  2] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C5 - L5[IO] C10 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  0] Utilization = 0.05 | pJ/Compute =   99.620 | L6[WIO] R3 C25 Q23 - L5[IO] S3 N2 P23 C5 - L4[] Q1 - L3[] Q1 C8Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [[  2  3]] Utilization =  Utilization = 0.060.01 | pJ/Compute =  | pJ/Compute =   99.682 102.743 |  | L6[WIO] R3 C25 Q23 - L5[IO] S3 N2 P23 C4 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1 L6[WIO] Q5 P35 C25 - L5[IO] S3 Q7 C4 N2 R3 - L4[] Q1 - L3[] Q1 - L2[I] Q1 - L1[W] C10 - L0[O] Q1
#
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  1] Utilization = 0.05 | pJ/Compute =   98.474 | L6[WIO] R3 C5 Q23 - L5[IO] S3 N2 P23 C25 - L4[] Q1 - L3[] Q1 C8Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  2] Utilization = 0.04 | pJ/Compute =   36.287 | L6[WIO] R3 P23 C4 N2 - L5[IO] C125 Q23 - L4[] Q1 - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  1] Utilization = 0.04 | pJ/Compute =   36.331 | L6[WIO] R3 P23 C5 N2 - L5[IO] C100 Q23 - L4[] Q1 - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.04 | pJ/Compute =   36.547 | L6[WIO] R3 P23 C10 N2 - L5[IO] C50 Q23 - L4[] Q1 - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   99.383 | L6[WIO] R3 C20 Q23 - L5[IO] S3 N2 P23 C5 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.09 | pJ/Compute =   82.126 | L6[WIO] N2 S3 R3 C25 - L5[IO] P11 C20 - L4[] Q1 Q11X - L3[] Q1 C2Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   82.060 | L6[WIO] N2 S3 R3 C10 - L5[IO] P11 C25 - L4[] Q1 Q11X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  140.305 | L6[WIO] Q7 P7 N2 S3 R3 C10 - L5[IO] P5 Q5 C10 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.04 | pJ/Compute =   36.201 | L6[WIO] R3 P23 C2 N2 - L5[IO] C250 Q23 - L4[] Q1 - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   38.712 | L6[WIO] N2 R3 C100 P7 - L5[IO] Q5 C2 P5 - L4[] Q1 Q7X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 400
#   Factorization options along problem dimension M = 1
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 3
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
# Mapspace Dimension [IndexFactorization] Size: 1200
# Mapspace Dimension [LoopPermutation] Size: 4
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 300 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.09 | pJ/Compute =   82.093 | [L6[WIO] N2 S3 R3 C20 - L5[IO] P11 C25 - L4[] Q1 Q11X - L3[] Q1 C2Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1   2
# ] Utilization = 0.06 | pJ/Compute =   33.924 | L6[WIO] S3 Q23 N2 C25 - L5[IO] C4 P23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  0] Utilization = 0.09 | pJ/Compute =   35.600 | L6[WIO] R3 N2 C2 - L5[IO] S3 C25 P11 - L4[] Q1 Q11X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.01 | pJ/Compute =  140.398 | L6[WIO] N2 C20 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C2Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.02 | pJ/Compute =  140.394 | L6[WIO] N2 C10 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C4Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  2] Utilization = 0.02 | pJ/Compute =  140.394 | L6[WIO] N2 C25 - L5[IO] C10 - L4[] Q1 - L3[] Q1 C4Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  140.385 | L6[WIO] N2 C25 - L5[IO] Q1 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   35.563 | L6[WIO] R3 N2 C8 - L5[IO] S3 C5 P11 - L4[] Q1 Q11X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  140.385 | L6[WIO] N2 C5 - L5[IO] C5 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  2] Utilization = 0.09 | pJ/Compute =   82.196 | L6[WIO] N2 S3 R3 C25 - L5[IO] P11 C10 - L4[] Q1 Q11X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  1] Utilization = 0.05 | pJ/Compute =   33.959 | L6[WIO] S3 Q23 N2 C5 - L5[IO] C25 P23 - L4[] Q1 - L3[] Q1 C8Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  140.385 | L6[WIO] N2 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  0] Utilization = 0.09 | pJ/Compute =   37.621 | [  1] Utilization = 0.09 | pJ/Compute =   35.563 | L6[WIO] R3 N2 C20 - L5[IO] S3 C2 P11 - L4[] Q1 Q11X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# L6[WIO] N2 R3 C125 P7 - L5[IO] Q5 P5 - L4[] Q1 Q7X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] C4 - L0[O] Q1
# [  2] Utilization = 0.09 | pJ/Compute =   35.563 | L6[WIO] R3 N2 C10 - L5[IO] S3 C4 P11 - L4[] Q1 Q11X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  0] Utilization = 0.01 | pJ/Compute =  140.398 | L6[WIO] N2 C25 - L5[IO] C20 - L4[] Q1 - L3[] Q1 C2Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =  140.392 | L6[WIO] N2 - L5[IO] C25 - L4[] Q1 - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C8 - L0[O] Q1
# [  0] Utilization = 0.05 | pJ/Compute =   33.959 | L6[WIO] S3 Q23 N2 C25 - L5[IO] C5 P23 - L4[] Q1 - L3[] Q1 C8Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   33.924 | L6[WIO] S3 Q23 N2 C20 - L5[IO] C5 P23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  140.206 | L6[WIO] Q7 P7 N2 S3 R3 C4 - L5[IO] P5 Q5 C25 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  141.840 | L6[WIO] C10 N2 - L5[IO] C10 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  2] Utilization = 0.09 | pJ/Compute =   40.898 | L6[WIO] N2 R3 C200 P7 - L5[IO] Q5 P5 - L4[] Q1 Q7X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  3] Utilization = 0.05 | pJ/Compute =  110.910 | L6[WIO] C25 N2 - L5[IO] Q1 - L4[] Q1 - L3[] Q1 C8Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  140.223 | L6[WIO] Q7 P7 N2 S3 R3 C5 - L5[IO] P5 Q5 C20 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C2 - L5[IO] C25 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] Q1 - L5[IO] C20 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C5 - L5[IO] C10 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C25 - L5[IO] C2 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  108.264 | L6[WIO] C10 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [[  0] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] C5 - L5[IO] C4 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
#   0] Utilization = 0.10 | pJ/Compute =   32.707 | L6[WIO] Q5 N2 C2 P7 R3 - L5[IO] S3 P5 C25 - L4[] Q1 Q7X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  0] Utilization = 0.07 | pJ/Compute =   17.290 | L6[WIO] C50 N2 R3 - L5[IO] P23 Q23 - L4[] Q1 - L3[] Q1 C4Y S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   32.860 | L6[WIO] Q5 N2 C8 P7 R3 - L5[IO] S3 P5 C5 - L4[] Q1 Q7X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   34.300 | L6[WIO] P7 C20 N2 Q7 - L5[IO] R3 P5 S3 C50 - L4[] Q1 Q5X - L3[] Q1 - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  107.759[  0] Utilization = 0.09 | pJ/Compute =   26.924 | L6[WIO] C25 P11 - L5[IO] C8 N2 R3 - L4[] Q1 Q11X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1  |
# L6[WIO] C4 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  2] Utilization = 0.09 | pJ/Compute =   32.909 | L6[WIO] Q5 N2 C10 P7 R3 - L5[IO] S3 P5 C4 - L4[] Q1 Q7X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  107.602 | L6[WIO] C2 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C10 - L0[O] Q1
# [  1] Utilization = 0.09 | pJ/Compute =   26.852 | [  2] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] C2 - L5[IO] C10 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# L6[WIO] C20 P11 - L5[IO] C10 N2 R3 - L4[] Q1 Q11X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.09 | pJ/Compute =   33.157 | L6[WIO] Q5 N2 C20 P7 R3 - L5[IO] S3 P5 C2 - L4[] Q1 Q7X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  0] Utilization = 0.07 | pJ/Compute =   19.327 | L6[WIO] C50 N2 R3 - L5[IO] P11 Q11 - L4[] Q1 - L3[] Q1 C4Y S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   26.679 | L6[WIO] C8 P11 - L5[IO] C25 N2 R3 - L4[] Q1 Q11X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  2] Utilization = 0.09 | pJ/Compute =   26.708 | L6[WIO] C10 P11 - L5[IO] C20 N2 R3 - L4[] Q1 Q11X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  107.514 | L6[WIO] C5 - L5[IO] N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C20 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  107.602 | L6[WIO] Q1 - L5[IO] C10 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C10 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] Q1 - L5[IO] C20 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.09 | pJ/Compute =   32.358 | L6[WIO] R3 C10 N2 - L5[IO] C5 Q5 P35 - L4[] Q1 Q7X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] C10 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] C2 - L5[IO] C10 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1 [  2] Utilization = 0.06 | pJ/Compute =  107.514 | L6[WIO] Q1 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C20 - L0[O] Q1
# [  2] Utilization = 0.04 | pJ/Compute =   18.159 | L6[WIO] C250 - L5[IO] R3 Q23 N2 P23 - L4[] Q1 - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
#
# [  0] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] C5 - L5[IO] C4 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  107.759 | L6[WIO] C4 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  107.514 | L6[WIO] Q1 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C20 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  107.602 | L6[WIO] C2 - L5[IO] C5 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C10 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   26.453 | L6[WIO] C5 - L5[IO] N2 S3 R3 P11 C10 - L4[] Q1 Q11X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.09 | pJ/Compute =   26.635 | L6[WIO] C25 - L5[IO] N2 S3 R3 P11 C2 - L4[] Q1 Q11X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  107.514 | L6[WIO] C5 - L5[IO] N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C20 - L0[O] Q1
# [  2] Utilization = 0.09 | pJ/Compute =   26.499 | L6[WIO] C10 - L5[IO] N2 S3 R3 P11 C5 - L4[] Q1 Q11X - L3[] Q1 C4Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [[  0] Utilization = 0.06 | pJ/Compute =  107.602 | L6[WIO] Q1 - L5[IO] C10 N2 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C10 - L0[O] Q1
#   1] Utilization = 0.09 | pJ/Compute =   26.474 | L6[WIO] N2 C25 - L5[IO] P11 S3 - L4[] Q1 Q11X - L3[] Q1 C10Y - L2[I] Q1 - L1[W] R3 C4 - L0[O] Q1
# [  0] Utilization = 0.08 | pJ/Compute =   20.824 | L6[WIO] C10 N2 P7 - L5[IO] C50 P5 R3 Q7 - L4[] Q1 Q5X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  2] Utilization = 0.10 | pJ/Compute =   26.437 | L6[WIO] N2 C5 - L5[IO] P11 C5 S3 - L4[] Q1 Q11X - L3[] Q1 C10Y - L2[I] Q1 - L1[W] R3 C4 - L0[O] Q1
# [  2] Utilization = 0.10 | pJ/Compute =   26.406 | L6[WIO] N2 P11 - L5[IO] C125 - L4[] Q1 Q11X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] R3 C8 - L0[O] Q1
# [  3] Utilization = 0.08 | pJ/Compute =   20.709 | L6[WIO] C2 N2 P7 - L5[IO] C250 P5 R3 Q7 - L4[] Q1 Q5X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [[  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#   1] Utilization = 0.08 | pJ/Compute =   20.752 | L6[WIO] C5 N2 P7 - L5[IO] C100 P5 R3 Q7 - L4[] Q1 Q5X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] Utilization = 0.08 | pJ/Compute =   20.738 | L6[WIO] C4 N2 P7 - L5[IO] C125 P5 R3 Q7 - L4[] Q1 Q5X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [[  1] Utilization = 0.03 | pJ/Compute =   20.264 | L6[WIO] N2 C100 Q23 - L5[IO] S3 C2 P23 - L4[] Q1 - L3[] Q1 C5Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
#   3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.09 | pJ/Compute =   19.178 | L6[WIO] N2 C20 R3 - L5[IO] C2 P35 S3 Q7 - L4[] Q1 Q5X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   21.653 | L6[WIO] C25 S3 - L5[IO] P23 N2 C4 R3 Q23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  2] Utilization = 0.09 | pJ/Compute =   19.178 | L6[WIO] N2 C10 R3 - L5[IO] C4 P35 S3 Q7 - L4[] Q1 Q5X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  3] Utilization = 0.10 | pJ/Compute =   26.415 | L6[WIO] N2 C4 - L5[IO] R3 P11 C50 - L4[] Q1 Q11X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C5 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   21.653 | L6[WIO] C20 S3 - L5[IO] P23 N2 C5 R3 Q23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] Utilization = 0.09 | pJ/Compute =   17.022 | L6[WIO] C50 - L5[IO] C5 N2 P35 Q7 - L4[] Q1 Q5X - L3[] Q1 C2Y S3Y - L2[I] Q1 - L1[W] R3 C2 - L0[O] Q1
# [  1] Utilization = 0.10 | pJ/Compute =   26.429 | L6[WIO] N2 C5 - L5[IO] P11 C25 S3 - L4[] Q1 Q11X - L3[] Q1 C8Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  3] Utilization = 0.09 | pJ/Compute =   19.038 | L6[WIO] C2 N2 P7 - L5[IO] C50 P5 R3 Q7 - L4[] Q1 Q5X - L3[] Q1 S3Y - L2[I] Q1 - L1[W] C10 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   20.882 | L6[WIO] C5 N2 S3 - L5[IO] Q23 R3 C10 P23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  1] Utilization = 0.07 | pJ/Compute =   35.848 | L6[WIO] P23 C5 N2 - L5[IO] R3 C50 Q23 - L4[] Q1 - L3[] Q1 C4Y S3Y - L2[I] Q1 - L1[W] Q1 - L0[O] Q1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.09 | pJ/Compute =   16.974 | L6[WIO] C125 - L5[IO] N2 P35 Q7 - L4[] Q1 Q5X - L3[] Q1 C4Y S3Y - L2[I] Q1 - L1[W] R3 C2 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   20.954 | L6[WIO] C10 N2 S3 - L5[IO] Q23 R3 C5 P23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   18.085 | L6[WIO] N2 C5 - L5[IO] S3 C10 R3 P23 Q23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =  107.514
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =  107.514
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.06 | pJ/Compute =   18.085 | L6[WIO] N2 C10 - L5[IO] S3 C5 R3 P23 Q23 - L4[] Q1 - L3[] Q1 C10Y - L2[I] Q1 - L1[W] C2 - L0[O] Q1
# [  1] Utilization = 0.21 | pJ/Compute =   34.041 | L6[WIO] N2 S3 C4 - L5[IO] C50 P11 - L4[] Q1 Q11X - L3[] Q1 C5Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.07 | pJ/Compute =   15.673 | L6[WIO] N2 C125 - L5[IO] Q23 P23 - L4[] Q1 - L3[] Q1 C4Y S3Y - L2[I] Q1 - L1[W] R3 C2 - L0[O] Q1
# [  1] Utilization = 0.22 | pJ/Compute =   33.912 | L6[WIO] N2 S3 C2 - L5[IO] C50 P11 - L4[] Q1 Q11X - L3[] Q1 C10Y - L2[I] Q1 - L1[W] R3 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.07 | pJ/Compute =   15.673
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.22 | pJ/Compute =   33.912
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.09 | pJ/Compute =   16.974

# %%
# !python3 copy_files.py

# %%
# !python3 run_example_designs.py --architecture eyeriss_like --problem CONV/DeepLabv3
# Out:
# Traceback (most recent call last):
#   File "run_example_designs.py", line 4, in <module>
#     import timeloopfe.v4 as tl
#   File "/usr/local/lib/python3.8/dist-packages/timeloopfe/__init__.py", line 1, in <module>
#     from .common import *
#   File "/usr/local/lib/python3.8/dist-packages/timeloopfe/common/__init__.py", line 1, in <module>
#     from .doc import *
#   File "/usr/local/lib/python3.8/dist-packages/timeloopfe/common/doc.py", line 2, in <module>
#     from .nodes import (
#   File "/usr/local/lib/python3.8/dist-packages/timeloopfe/common/nodes.py", line 23, in <module>
#     import accelergy.utils.yaml as yaml
#   File "/usr/local/lib/python3.8/dist-packages/accelergy/utils/yaml.py", line 28, in <module>
#     from accelergy.utils.utils import INFO
#   File "/usr/local/lib/python3.8/dist-packages/accelergy/utils/utils.py", line 24, in <module>
#     from copy import deepcopy
# ImportError: cannot import name 'deepcopy' from 'copy' (/home/workspace/final-project/example_designs/copy.py)
