# %%
# !find ../../../workspace -type d -name ".ipynb_checkpoints" -exec rm -rf {} +

# %%
# !python3 rename.py

# %%
# !python3 run_example_designs.py --architecture simple_output_stationary --problem CONV/UndilatedDeepLabv3
# Out:
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer22...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer5...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer34...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer18...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer59...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer9...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer38...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer43...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer14...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer54...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer55...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer15...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer39...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer42...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer8...
#
#
# Running mapper for target simple_output_stationary in /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer58...
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer34/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer22/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer14/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer58/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer59/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer5/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer39/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer54/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer15/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer55/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer42/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer18/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer34/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer8/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer38/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer9/parsed-processed-input.yaml
# input file: /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer43/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer59/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer58/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer54/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer22/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer14/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer55/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer5/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer42/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer15/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer39/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer9/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer43/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer8/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer18/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/final-project/example_designs/example_designs/simple_output_stationary/outputs/UndilatedDeepLabv3_layer38/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 715
#   Factorization options along problem dimension M = 330
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 4
#   Factorization options along problem dimension Q = 4
# Mapspace Dimension [IndexFactorization] Size: 33976800
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 8494200 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.06 | pJ/Compute =   41.206 | L6[WIO] N2 C4 Q29 - L5[] M16 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   37.231 | L6[WIO] N2 C4 Q29 - L5[W] M16 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   39.669 | L6[WIO] N2 Q29 - L5[] M16 C4 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   35.614 | L6[WIO] N2 Q29 - L5[W] M16 C4 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   10.743 | L6[WIO] N2 Q29 - L5[I] M16 C4 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   12.281 | L6[WIO] N2 C4 Q29 - L5[I] M16 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =    8.306 | L6[WIO] N2 C4 Q29 - L5[WI] M16 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   40.181 | L6[WIO] N2 C2 Q29 - L5[] M16 C2 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   36.206 | L6[WIO] N2 C2 Q29 - L5[W] M16 C2 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =   39.672 | L6[WIO] N2 Q29 - L5[] M16 C8 - L4[] Q1 M4Y C2Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =   35.618 | L6[WIO] N2 Q29 - L5[W] M16 C8 - L4[] Q1 M4Y C2Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =   10.747 | L6[WIO] N2 Q29 - L5[I] M16 C8 - L4[] Q1 M4Y C2Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   11.256 | L6[WIO] N2 C2 Q29 - L5[I] M16 C2 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =    7.281 | L6[WIO] N2 C2 Q29 - L5[WI] M16 C2 - L4[] Q1 M4Y C4Y - L3[O] M2 C32 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  3] Utilization = 0.06 | pJ/Compute =    8.971 | L6[WIO] Q29 M2 N2 - L5[WI] M8 C32 - L4[] Q1 M8Y C2Y - L3[O] C8 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 1001
#   Factorization options along problem dimension M = 495
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 7
#   Factorization options along problem dimension Q = 7
# Mapspace Dimension [IndexFactorization] Size: 218513295
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 54628324 Residue: 1
# Mapspace construction complete.
# Search configuration complete.
# [  0] Utilization = 0.06 | pJ/Compute =   72.606 | L6[WIO] C64 - L5[] P3 M64 C4 - L4[] Q1 M4Y C4Y - L3[O] N2 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   60.096 | L6[WIO] C64 - L5[W] P3 M64 C4 - L4[] Q1 M4Y C4Y - L3[O] N2 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   43.155 | L6[WIO] C64 - L5[I] P3 M64 C4 - L4[] Q1 M4Y C4Y - L3[O] N2 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   30.645 | L6[WIO] C64 - L5[WI] P3 M64 C4 - L4[] Q1 M4Y C4Y - L3[O] N2 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.01 | pJ/Compute =  196.684 | L6[WIO] Q3 P3 N2 M16 C16 - L5[] M8 - L4[] Q1 M2Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   28.312 | L6[WIO] C64 - L5[IO] P3 M64 C4 - L4[] Q1 M4Y C4Y - L3[O] N2 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   15.802 | L6[WIO] C64 - L5[WIO] P3 M64 C4 - L4[] Q1 M4Y C4Y - L3[O] N2 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# [  2] Utilization = 0.01 | pJ/Compute =  145.140 | L6[WIO] Q3 P3 N2 M16 C16 - L5[I] M8 - L4[] Q1 M2Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.01 | pJ/Compute =  194.654 | L6[WIO] Q3 P3 N2 M16 C8 - L5[] M8 C2 - L4[] Q1 M2Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.01 | pJ/Compute =  143.109 | L6[WIO] Q3 P3 N2 M16 C8 - L5[I] M8 C2 - L4[] Q1 M2Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =  165.082 | L6[WIO] M2 P3 C8 - L5[] M2 C16 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   67.600 | L6[WIO] M2 P3 C8 - L5[W] M2 C16 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.01 | pJ/Compute =  141.610 | L6[WIO] Q3 P3 N2 M16 C16 - L5[IO] M8 - L4[] Q1 M2Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   66.777 | L6[WIO] M2 P3 C8 - L5[WI] M2 C16 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.01 | pJ/Compute =  141.466 | L6[WIO] Q3 P3 N2 M16 C8 - L5[IO] M8 C2 - L4[] Q1 M2Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   37.671 | L6[WIO] M2 P3 C8 - L5[WO] M2 C16 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  1] Utilization = 0.03 | pJ/Compute =   36.849 | L6[WIO] M2 P3 C8 - L5[WIO] M2 C16 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 495
#   Factorization options along problem dimension M = 210
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 16
#   Factorization options along problem dimension Q = 16
# Mapspace Dimension [IndexFactorization] Size: 239500800
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 59875200 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  3] Utilization = 0.06 | pJ/Compute =  155.967 | L6[WIO] Q3 - L5[] M64 C4 P19 Q19 - L4[] Q1 N2Y C8Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  136.004 | L6[WIO] Q3 - L5[W] M64 C4 P19 Q19 - L4[] Q1 N2Y C8Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  155.967 | L6[WIO] C2 Q3 - L5[] M64 C2 P19 Q19 - L4[] Q1 N2Y C8Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =  160.005 | L6[WIO] Q3 - L5[] M64 C8 P19 Q19 - L4[] Q1 N2Y C4Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.03 | pJ/Compute =  140.042 | L6[WIO] Q3 - L5[W] M64 C8 P19 Q19 - L4[] Q1 N2Y C4Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  155.967 | L6[WIO] C4 Q3 - L5[] M64 P19 Q19 - L4[] Q1 N2Y C8Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =  136.004 | L6[WIO] C4 Q3 - L5[W] M64 P19 Q19 - L4[] Q1 N2Y C8Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =  136.004 | L6[WIO] C2 Q3 - L5[W] M64 C2 P19 Q19 - L4[] Q1 N2Y C8Y - L3[O] C8 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# [  2] Utilization = 0.03 | pJ/Compute =  165.082 | L6[WIO] M2 P3 C4 - L5[] M2 C32 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   67.600 | L6[WIO] M2 P3 C4 - L5[W] M2 C32 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   52.953 | L6[WIO] Q57 N2 - L5[I] C32 P3 M32 - L4[] Q1 C8Y - L3[O] M2 - L2[W] P19 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   46.663 | L6[WIO] Q57 N2 - L5[WI] C32 P3 M32 - L4[] Q1 C8Y - L3[O] M2 - L2[W] P19 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   66.777 | L6[WIO] M2 P3 C4 - L5[WI] M2 C32 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   37.671 | L6[WIO] M2 P3 C4 - L5[WO] M2 C32 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =  149.080 | L6[WIO] M2 P3 C32 - L5[] M2 C2 Q3 N2 - L4[] Q1 M8Y C2Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   36.849 | L6[WIO] M2 P3 C4 - L5[WIO] M2 C32 Q3 N2 - L4[] Q1 M8Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   51.597 | L6[WIO] M2 P3 C32 - L5[W] M2 C2 Q3 N2 - L4[] Q1 M8Y C2Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  1] Utilization = 0.03 | pJ/Compute =   23.750 | L6[WIO] Q57 N2 - L5[IO] C32 P3 M32 - L4[] Q1 C8Y - L3[O] M2 - L2[W] P19 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   50.775 | L6[WIO] M2 P3 C32 - L5[WI] M2 C2 Q3 N2 - L4[] Q1 M8Y C2Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   17.460 | L6[WIO] Q57 N2 - L5[WIO] C32 P3 M32 - L4[] Q1 C8Y - L3[O] M2 - L2[W] P19 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   36.754 | L6[WIO] M2 P3 C32 - L5[WO] M2 C2 Q3 N2 - L4[] Q1 M8Y C2Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   35.932 | L6[WIO] M2 P3 C32 - L5[WIO] M2 C2 Q3 N2 - L4[] Q1 M8Y C2Y - L3[O] C8 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   25.618 | L6[WIO] Q57 N2 - L5[IO] C64 P3 M32 - L4[] Q1 C4Y - L3[O] M2 - L2[W] P19 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   19.328 | L6[WIO] Q57 N2 - L5[WIO] C64 P3 M32 - L4[] Q1 C4Y - L3[O] M2 - L2[W] P19 - L1[I] Q1 - L0[O] Q1
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 1001
#   Factorization options along problem dimension M = 495
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 64
#   Factorization options along problem dimension Q = 7
# Mapspace Dimension [IndexFactorization] Size: 1997835840
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 499458960 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  2] Utilization = 0.06 | pJ/Compute =   20.699 | L6[WIO] M4 Q3 P3 - L5[W] N2 C2 - L4[] Q1 M2Y C8Y - L3[O] C64 M32 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   18.379 | L6[WIO] N2 M2 C16 - L5[I] M4 Q29 C16 - L4[] Q1 M8Y C2Y - L3[O] M2 P29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   14.404 | L6[WIO] N2 M2 C16 - L5[WI] M4 Q29 C16 - L4[] Q1 M8Y C2Y - L3[O] M2 P29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   57.235 | L6[WIO] M2 Q3 P43 C4 - L5[] M8 C16 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   48.462 | L6[WIO] M2 Q3 P43 C4 - L5[W] M8 C16 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   28.310 | L6[WIO] M2 Q3 P43 C4 - L5[I] M8 C16 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   58.260 | L6[WIO] M2 Q3 P43 C8 - L5[] M8 C8 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   56.723 | L6[WIO] M2 Q3 P43 C2 - L5[] M8 C32 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   86.931 | L6[WIO] C8 - L5[] M16 N2 P129 C2 Q3 - L4[] Q1 M8Y C2Y - L3[O] C32 M2 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   47.950 | L6[WIO] M2 Q3 P43 C2 - L5[W] M8 C32 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   27.065 | L6[WIO] C8 - L5[W] M16 N2 P129 C2 Q3 - L4[] Q1 M8Y C2Y - L3[O] C32 M2 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   27.797 | L6[WIO] M2 Q3 P43 C2 - L5[I] M8 C32 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   19.537 | L6[WIO] M2 Q3 P43 C4 - L5[WI] M8 C16 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   49.487 | L6[WIO] M2 Q3 P43 C8 - L5[W] M8 C8 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   29.335 | L6[WIO] M2 Q3 P43 C8 - L5[I] M8 C8 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   27.568 | L6[WIO] M2 Q3 P43 C2 - L5[IO] M8 C32 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   24.273 | L6[WIO] P19 M8 C64 - L5[O] N2 C4 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   23.966 | [L6[WIO] P19 M8 C64 - L5[WO] N2 C4 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
#   0] Utilization = 0.06 | pJ/Compute =   20.562 | L6[WIO] M2 Q3 P43 C8 - L5[WI] M8 C8 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   18.836 | L6[WIO] M2 Q3 P43 C4 - L5[WIO] M8 C16 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# [  0] Utilization = 0.03 | pJ/Compute =   36.061 | L6[WIO] P19 M8 C256 - L5[O] N2 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   18.918 | L6[WIO] M2 Q3 P43 C8 - L5[WIO] M8 C8 - L4[] Q1 M4Y C4Y - L3[O] N2 C4 M4 - L2[W] P6 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  3] Utilization = 0.03 | pJ/Compute =   51.449 | L6[WIO] P19 M8 C32 - L5[] N2 C8 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   51.141 | L6[WIO] P19 M8 C32 - L5[W] N2 C8 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
# [[  3] Utilization = 0.03 | pJ/Compute =   22.246 | L6[WIO] P19 M8 C32 - L5[O] N2 C8 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   21.938 | L6[WIO] P19 M8 C32 - L5[WO] N2 C8 - L4[] Q1 M8Y - L3[O] Q3 P3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
#   2] Utilization = 0.06 | pJ/Compute =   27.065 | L6[WIO] C16 - L5[W] M16 N2 P129 Q3 - L4[] Q1 M8Y C2Y - L3[O] C32 M2 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   34.077 | L6[WIO] M2 Q19 P57 C4 - L5[WIO] N2 C16 - L4[] Q1 M8Y C2Y - L3[O] C2 M4 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 495
#   Factorization options along problem dimension M = 1001
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 25
#   Factorization options along problem dimension Q = 25
# Mapspace Dimension [IndexFactorization] Size: 2787159375
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 696789844 Residue: 1
# Mapspace construction complete.
# Search configuration complete.
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# [  0] Utilization = 0.06 | pJ/Compute =   15.051 | L6[WIO] C16 - L5[I] M2 C64 - L4[] Q1 M16Y - L3[O] M8 N2 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   11.522 | L6[WIO] C16 - L5[IO] M2 C64 - L4[] Q1 M16Y - L3[O] M8 N2 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  1] Utilization = 0.06 | pJ/Compute =   49.243 | L6[WIO] C4 M2 Q3 P3 - L5[W] N2 M32 - L4[] Q1 M4Y C4Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.05 | pJ/Compute =   20.318 | L6[WIO] C4 M2 Q3 P3 - L5[WI] N2 M32 - L4[] Q1 M4Y C4Y - L3[O] C64 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  0] Utilization = 0.02 | pJ/Compute =  188.866 | L6[WIO] C2 Q3 M64 - L5[] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =  165.782 | L6[WIO] C2 Q3 M64 - L5[W] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   69.092 | L6[WIO] C2 Q3 M64 - L5[I] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   46.008 | L6[WIO] C2 Q3 M64 - L5[WI] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   40.915 | L6[WIO] C2 Q3 M64 - L5[IO] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   17.831 | L6[WIO] C2 Q3 M64 - L5[WIO] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# Initializing Index Factorization subspace.
# [  3] Utilization = 0.06 | pJ/Compute =   20.672 | L6[WIO] P43 N2 - L5[IO] C512 M32 - L4[] Q1 M8Y C2Y - L3[O] Q3 P6 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 495
#   Factorization options along problem dimension M = 715
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 4
#   Factorization options along problem dimension Q = 4
# Mapspace Dimension [IndexFactorization] Size: 50965200
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 12741300 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  0] Utilization = 0.02 | pJ/Compute =   15.939 | L6[WIO] M8 C8 Q15 - L5[W] P15 C4 - L4[] Q1 N2Y C2Y - L3[O] C4 M128 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =  172.828 | L6[WIO] C16 Q3 M64 - L5[] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =  149.744 | L6[WIO] C16 Q3 M64 - L5[W] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [[  1] Utilization = 0.03 | pJ/Compute =   53.054 | L6[WIO] C16 Q3 M64 - L5[I] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [Initializing Index Factorization subspace.
#   0] Utilization = 0.02 | pJ/Compute =  103.312 | L6[WIO] M8 C4 - L5[] M16 C16 N2 P29 - L4[] Q1 M4Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   99.258 | L6[WIO] M8 C4 - L5[W] M16 C16 N2 P29 - L4[] Q1 M4Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
#   1] Utilization = 0.03 | pJ/Compute =   29.970 | L6[WIO] C16 Q3 M64 - L5[WI] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   71.302 | L6[WIO] M8 C8 - L5[] M16 C4 N2 P29 - L4[] Q1 M4Y C2Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 495
#   Factorization options along problem dimension M = 1001
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 25
#   Factorization options along problem dimension Q = 25
# Mapspace Dimension [IndexFactorization] Size: 2787159375
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 696789844 Residue: 1
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.03 | pJ/Compute =   71.302 | L6[WIO] M8 C16 - L5[] M16 C2 N2 P29 - L4[] Q1 M4Y C2Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   71.302 | L6[WIO] M8 C4 - L5[] M16 C8 N2 P29 - L4[] Q1 M4Y C2Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   67.248 | L6[WIO] M8 C4 - L5[W] M16 C8 N2 P29 - L4[] Q1 M4Y C2Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   67.248 | L6[WIO] M8 C8 - L5[W] M16 C4 N2 P29 - L4[] Q1 M4Y C2Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   67.248 | L6[WIO] M8 C16 - L5[W] M16 C2 N2 P29 - L4[] Q1 M4Y C2Y - L3[O] C4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   18.498 | L6[WIO] C2 - L5[] M2 C512 - L4[] Q1 M16Y - L3[O] M8 N2 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   11.530 | L6[WIO] C2 - L5[I] M2 C512 - L4[] Q1 M16Y - L3[O] M8 N2 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   57.851 | L6[WIO] C2 M2 P15 - L5[] Q5 M4 - L4[] Q1 N2Y M4Y C2Y - L3[O] M32 C64 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =  146.832 | L6[WIO] M32 N2 - L5[] P29 C8 Q29 - L4[] Q1 M2Y C8Y - L3[O] C4 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =  172.828 | L6[WIO] C16 Q3 M64 - L5[] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =  149.744 | L6[WIO] C16 Q3 M64 - L5[W] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   53.054 | L6[WIO] C16 Q3 M64 - L5[I] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   29.970 | L6[WIO] C16 Q3 M64 - L5[WI] Q5 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   11.300 | L6[WIO] C2 - L5[IO] M2 C512 - L4[] Q1 M16Y - L3[O] M8 N2 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   38.165 | L6[WIO] C2 M2 P15 - L5[W] Q5 M4 - L4[] Q1 N2Y M4Y C2Y - L3[O] M32 C64 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   28.137 | L6[WIO] C2 M2 P15 - L5[I] Q5 M4 - L4[] Q1 N2Y M4Y C2Y - L3[O] M32 C64 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.02 | pJ/Compute =   11.889 | L6[WIO] M8 C4 Q15 - L5[W] P15 C8 - L4[] Q1 N2Y C2Y - L3[O] C4 M128 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   20.928 | L6[WIO] C2 P43 N2 - L5[IO] C256 M32 - L4[] Q1 M8Y C2Y - L3[O] Q3 P6 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =  172.828 | L6[WIO] C4 Q3 M64 - L5[] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =  149.744 | L6[WIO] C4 Q3 M64 - L5[W] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   53.054 | L6[WIO] C4 Q3 M64 - L5[I] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   27.006 | L6[WIO] M32 N2 - L5[W] P29 C8 Q29 - L4[] Q1 M2Y C8Y - L3[O] C4 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =  172.828 | L6[WIO] C8 Q3 M64 - L5[] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   20.432 | L6[WIO] M32 N2 - L5[WO] P29 C8 Q29 - L4[] Q1 M2Y C8Y - L3[O] C4 M8 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =  172.828 | L6[WIO] C8 Q3 M64 - L5[] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =  149.744 | L6[WIO] C8 Q3 M64 - L5[W] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# [  2] Utilization = 0.03 | pJ/Compute =   53.054 | L6[WIO] C8 Q3 M64 - L5[I] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   29.970 | L6[WIO] C8 Q3 M64 - L5[WI] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.02 | pJ/Compute =   11.889 | L6[WIO] M8 C4 Q15 - L5[W] P15 C8 - L4[] Q1 N2Y C2Y - L3[O] C4 M128 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   11.253 | L6[WIO] C4 Q29 M2 - L5[I] N2 M4 - L4[] Q1 M8Y C2Y - L3[O] M2 C64 P29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    9.438 | L6[WIO] C4 Q29 M2 - L5[WI] N2 M4 - L4[] Q1 M8Y C2Y - L3[O] M2 C64 P29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   29.970 | L6[WIO] C4 Q3 M64 - L5[WI] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   23.031 | L6[WIO] C8 Q3 M64 - L5[WIO] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =  188.866 | L6[WIO] C2 Q3 M64 - L5[] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1 [  3] Utilization = 0.03 | pJ/Compute =   18.929 | L6[WIO] C4 Q3 M64 - L5[WIO] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
#
# [  2] Utilization = 0.03 | pJ/Compute =  149.744 | L6[WIO] C8 Q3 M64 - L5[W] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   53.054 | L6[WIO] C8 Q3 M64 - L5[I] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   29.970 | L6[WIO] C8 Q3 M64 - L5[WI] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =  165.782 | L6[WIO] C2 Q3 M64 - L5[W] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   23.375 | L6[WIO] M4 C16 Q3 P15 - L5[WI] Q5 M32 - L4[] Q1 N2Y M4Y - L3[O] M2 C16 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   69.092 | L6[WIO] C2 Q3 M64 - L5[I] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   46.008 | L6[WIO] C2 Q3 M64 - L5[WI] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.02 | pJ/Compute =    9.865 | L6[WIO] M8 C2 Q15 - L5[W] P15 C16 - L4[] Q1 N2Y C2Y - L3[O] C4 M128 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   40.915 | L6[WIO] C2 Q3 M64 - L5[IO] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   69.258 | L6[WIO] M2 Q19 P57 C8 - L5[] N2 C8 - L4[] Q1 M8Y C2Y - L3[O] C2 M4 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   17.831 | [  0] Utilization = 0.06 | pJ/Compute =   15.892 | L6[WIO] C8 P43 N2 - L5[WIO] C64 M32 - L4[] Q1 M8Y C2Y - L3[O] Q3 P6 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   51.713 | L6[WIO] M2 Q19 P57 C8 - L5[W] N2 C8 - L4[] Q1 M8Y C2Y - L3[O] C2 M4 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1 L6[WIO] C2 Q3 M64 - L5[WIO] Q5 C16 P3 M8 N2 - L4[] Q1 C4Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.03 | pJ/Compute =   23.031 | L6[WIO] C8 Q3 M64 - L5[WIO] Q5 C2 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
#
# [  0] Utilization = 0.06 | pJ/Compute =   40.929 | L6[WIO] M2 Q19 P57 C8 - L5[WI] N2 C8 - L4[] Q1 M8Y C2Y - L3[O] C2 M4 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   34.355 | L6[WIO] M2 Q19 P57 C8 - L5[WIO] N2 C8 - L4[] Q1 M8Y C2Y - L3[O] C2 M4 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   27.125 | L6[WIO] M2 P15 - L5[I] Q5 M4 C2 - L4[] Q1 N2Y M4Y C2Y - L3[O] M32 C64 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.02 | pJ/Compute =   15.939 | L6[WIO] M8 C8 Q15 - L5[W] P15 C4 - L4[] Q1 N2Y C2Y - L3[O] C4 M128 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# [  2] Utilization = 0.03 | pJ/Compute =   15.326 | L6[WIO] M4 C8 Q3 P15 - L5[WI] Q5 M32 C2 - L4[] Q1 N2Y M4Y - L3[O] M2 C16 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.02 | pJ/Compute =    9.865 | L6[WIO] M8 C2 Q15 - L5[W] P15 C16 - L4[] Q1 N2Y C2Y - L3[O] C4 M128 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =  172.828 | L6[WIO] C4 Q3 M64 - L5[] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension G = 1
#   Factorization options along problem dimension C = 330
#   Factorization options along problem dimension M = 715
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 9
#   Factorization options along problem dimension P = 4
#   Factorization options along problem dimension Q = 4
# Mapspace Dimension [IndexFactorization] Size: 33976800
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 8494200 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  3] Utilization = 0.03 | pJ/Compute =  149.744 | L6[WIO] C4 Q3 M64 - L5[W] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   53.054 | L6[WIO] C4 Q3 M64 - L5[I] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   29.970 | L6[WIO] C4 Q3 M64 - L5[WI] Q5 C4 P3 M8 N2 - L4[] Q1 C8Y - L3[O] C2 M2 - L2[W] P5 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.03 | pJ/Compute =   23.922 | L6[WIO] M32 Q29 - L5[] N2 M2 C2 - L4[] Q1 M8Y - L3[O] C128 - L2[W] P29 - L1[I] Q1 - L0[O] Q1
# ...
# [  0] Utilization = 0.06 | pJ/Compute =   17.246 | L6[WIO] C4 P19 - L5[W] Q57 N2 C2 - L4[] Q1 M16Y - L3[O] C32 M4 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   11.854 | L6[WIO] C4 P19 - L5[WI] Q57 N2 C2 - L4[] Q1 M16Y - L3[O] C32 M4 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =    9.164 | L6[WIO] M2 P29 Q29 - L5[WI] M2 C16 - L4[] Q1 M16Y - L3[O] C8 M8 N2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   25.339 | L6[WIO] P5 Q3 M16 - L5[W] Q5 M4 C2 - L4[] Q1 M8Y C2Y - L3[O] M2 C64 N2 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   10.482 | L6[WIO] P5 Q3 M16 - L5[WI] Q5 M4 C2 - L4[] Q1 M8Y C2Y - L3[O] M2 C64 N2 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =    6.601 | L6[WIO] P29 M8 - L5[WI] C8 S3 R3 - L4[] Q1 M16Y - L3[O] N2 C16 Q29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    9.981 | L6[WIO] C8 P29 M8 - L5[I] S3 R3 - L4[] Q1 M16Y - L3[O] N2 C16 Q29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    8.166 | L6[WIO] C8 P29 M8 - L5[WI] S3 R3 - L4[] Q1 M16Y - L3[O] N2 C16 Q29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   13.001 | L6[WIO] C4 Q3 M64 - L5[IO] C8 M2 N2 - L4[] Q1 M4Y C4Y - L3[O] C2 M2 Q5 P5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   12.299 | L6[WIO] C4 Q3 M64 - L5[WIO] C8 M2 N2 - L4[] Q1 M4Y C4Y - L3[O] C2 M2 Q5 P5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   17.079 | L6[WIO] N2 M64 Q5 - L5[WI] Q3 M8 C4 - L4[] Q1 M2Y C8Y - L3[O] C8 P15 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    9.798 | L6[WIO] Q57 N2 - L5[WI] M16 C32 - L4[] Q1 M2Y C8Y - L3[O] M2 P19 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   14.755 | L6[WIO] P2 M8 C16 R3 - L5[WI] P8 M16 - L4[] Q1 C16Y - L3[O] C4 M2 S3 - L2[W] N2 P16 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   13.525 | L6[WIO] P2 M8 C16 R3 - L5[WIO] P8 M16 - L4[] Q1 C16Y - L3[O] C4 M2 S3 - L2[W] N2 P16 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   16.132 | L6[WIO] M2 P29 Q29 - L5[W] M2 C32 - L4[] Q1 M16Y - L3[O] C4 M8 N2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =    9.164 | L6[WIO] M2 P29 Q29 - L5[WI] M2 C32 - L4[] Q1 M16Y - L3[O] C4 M8 N2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   15.233 | L6[WIO] C2 P19 - L5[W] Q57 N2 C4 - L4[] Q1 M16Y - L3[O] C32 M4 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =    9.841 | L6[WIO] C2 P19 - L5[WI] Q57 N2 C4 - L4[] Q1 M16Y - L3[O] C32 M4 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   17.103 | L6[WIO] C8 Q3 M64 - L5[IO] C4 M2 N2 - L4[] Q1 M4Y C4Y - L3[O] C2 M2 Q5 P5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   16.401 | L6[WIO] C8 Q3 M64 - L5[WIO] C4 M2 N2 - L4[] Q1 M4Y C4Y - L3[O] C2 M2 Q5 P5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =    9.103 | L6[WIO] M2 P57 N2 - L5[WIO] C4 M2 - L4[] Q1 M8Y - L3[O] C64 M2 Q3 - L2[W] Q19 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.03 | pJ/Compute =   14.897 | L6[WIO] M2 P2 C128 - L5[WIO] S3 M128 - L4[] Q1 N2Y C4Y - L3[O] C2 P64 R3 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    9.586 | L6[WIO] M2 N2 Q5 C32 - L5[WIO] C2 P5 M2 - L4[] Q1 M16Y - L3[O] C16 M4 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    9.687 | L6[WIO] Q29 M2 - L5[I] N2 M16 C8 - L4[] Q1 M8Y C2Y - L3[O] C8 M2 P29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    7.872 | L6[WIO] Q29 M2 - L5[WI] N2 M16 C8 - L4[] Q1 M8Y C2Y - L3[O] C8 M2 P29 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   10.950 | L6[WIO] C2 Q3 M64 - L5[IO] C16 M2 N2 - L4[] Q1 M4Y C4Y - L3[O] C2 M2 Q5 P5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   10.248 | L6[WIO] C2 Q3 M64 - L5[WIO] C16 M2 N2 - L4[] Q1 M4Y C4Y - L3[O] C2 M2 Q5 P5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   15.157 | L6[WIO] M2 P19 C32 - L5[WIO] Q19 M8 - L4[] Q1 N2Y M2Y C4Y - L3[O] M2 C2 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.06 | pJ/Compute =   27.146 | L6[WIO] S3 C16 P2 M8 - L5[I] C16 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [[  1] Utilization = 0.06 | pJ/Compute =    7.196 | L6[WIO] C4 P5 M4 - L5[WI] M2 Q3 - L4[] Q1 M8Y C2Y - L3[O] C128 M4 N2 Q5 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
#   3] Utilization = 0.06 | pJ/Compute =   25.798 | L6[WIO] S3 C16 P2 M8 - L5[WI] C16 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   15.714 | L6[WIO] S3 C16 P2 M8 - L5[O] C16 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   14.366 | L6[WIO] S3 C16 P2 M8 - L5[WO] C16 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =    8.398 | L6[WIO] S3 C16 P2 M8 - L5[IO] C16 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =    7.050 | L6[WIO] S3 C16 P2 M8 - L5[WIO] C16 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =   15.734 | L6[WIO] S3 C32 P2 M8 - L5[WO] C8 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =    9.766 | L6[WIO] S3 C32 P2 M8 - L5[IO] C8 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =    8.418 | L6[WIO] S3 C32 P2 M8 - L5[WIO] C8 P2 M2 - L4[] Q1 M16Y - L3[O] N2 C4 R3 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    5.657
# [  1] Utilization = 0.06 | pJ/Compute =   15.978 | L6[WIO] P5 M128 - L5[I] Q3 - L4[] Q1 N2Y C8Y - L3[O] C32 M8 Q5 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   10.192 | L6[WIO] C4 M8 N2 - L5[WIO] C4 M8 Q5 - L4[] Q1 M8Y C2Y - L3[O] M2 C8 P5 - L2[W] P3 Q3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   13.476 | L6[WIO] P5 M128 - L5[WI] Q3 - L4[] Q1 N2Y C8Y - L3[O] C32 M8 Q5 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  1] Utilization = 0.06 | pJ/Compute =    8.339 | L6[WIO] P29 M4 C2 - L5[WIO] M2 N2 C2 - L4[] Q1 M16Y - L3[O] M4 C32 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   17.258 | L6[WIO] P16 M4 C32 - L5[WIO] P2 M32 C2 - L4[] Q1 C16Y - L3[O] M2 N2 S3 R3 - L2[W] P8 - L1[I] Q1 - L0[O] Q1
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    6.086
# [  1] Utilization = 0.06 | pJ/Compute =   10.509 | L6[WIO] P5 M128 - L5[I] N2 C8 - L4[] Q1 M2Y C8Y - L3[O] C4 M4 Q15 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =    9.339 | L6[WIO] P5 M128 - L5[WI] N2 C8 - L4[] Q1 M2Y C8Y - L3[O] C4 M4 Q15 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =    8.796 | L6[WIO] M8 Q5 - L5[WI] M8 C2 N2 P5 - L4[] Q1 M4Y C4Y - L3[O] M4 C32 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   16.534 | L6[WIO] M4 R3 C32 P8 S3 - L5[IO] M32 P2 - L4[] Q1 N2Y M2Y C4Y - L3[O] C8 P8 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   14.889 | L6[WIO] M4 R3 C32 P8 S3 - L5[WIO] M32 P2 - L4[] Q1 N2Y M2Y C4Y - L3[O] C8 P8 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] Utilization = 0.06 | pJ/Compute =    9.187 | L6[WIO] P29 M4 - L5[I] M2 N2 C4 - L4[] Q1 M16Y - L3[O] M4 C32 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 0.06 | pJ/Compute =    7.372 | L6[WIO] P29 M4 - L5[WI] M2 N2 C4 - L4[] Q1 M16Y - L3[O] M4 C32 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =   13.194 | L6[WIO] M4 R3 C16 P8 S3 - L5[WIO] M32 P2 C2 - L4[] Q1 N2Y M2Y C4Y - L3[O] C8 P8 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =   14.839 | L6[WIO] P32 M4 C32 - L5[WIO] R3 M8 S3 P2 - L4[] Q1 N2Y M8Y - L3[O] C32 P2 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 0.06 | pJ/Compute =    8.861 | L6[WIO] M8 P2 C32 - L5[WIO] C2 R3 M4 P8 - L4[] Q1 N2Y M8Y - L3[O] C16 P16 S3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   13.417 | L6[WIO] P19 N2 - L5[WI] M2 C4 Q57 - L4[] Q1 M4Y C4Y - L3[O] M8 C16 P3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.06 | pJ/Compute =    7.688 | L6[WIO] P5 M256 - L5[WI] P3 N2 C8 - L4[] Q1 M4Y C4Y - L3[O] C8 - L2[W] Q15 - L1[I] Q1 - L0[O] Q1
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    5.698
# [  0] Utilization = 0.06 | pJ/Compute =   11.928 | L6[WIO] C16 P2 M8 N2 R3 - L5[WIO] C32 P32 - L4[] Q1 M8Y C2Y - L3[O] M4 S3 - L2[W] P4 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    8.263 | L6[WIO] M4 P5 C4 Q3 - L5[WI] M4 C128 - L4[] Q1 M16Y - L3[O] C2 N2 P3 - L2[W] Q5 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =   13.009 | L6[WIO] C2 Q19 - L5[I] P3 M2 C2 Q3 - L4[] Q1 N2Y M8Y - L3[O] C64 M4 P19 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =    9.874 | L6[WIO] C2 Q19 - L5[WI] P3 M2 C2 Q3 - L4[] Q1 N2Y M8Y - L3[O] C64 M4 P19 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] Utilization = 0.06 | pJ/Compute =    7.571 | L6[WIO] P29 R3 M2 - L5[WIO] S3 N2 M2 C4 - L4[] Q1 M8Y C2Y - L3[O] C16 M4 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.06 | pJ/Compute =    6.033 | L6[WIO] S3 C8 M2 P4 - L5[I] M8 R3 C64 - L4[] Q1 N2Y M8Y - L3[O] C2 M2 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.06 | pJ/Compute =   10.192 | L6[WIO] C4 M8 N2 - L5[WIO] C4 M8 Q5 - L4[] Q1 M8Y C2Y - L3[O] M2 C8 P5 - L2[W] P3 Q3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 0.06 | pJ/Compute =    7.480 | L6[WIO] M16 C4 - L5[WIO] C2 M4 Q5 - L4[] Q1 N2Y M8Y - L3[O] M2 C32 P5 - L2[W] P3 Q3 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  2] Utilization = 0.06 | pJ/Compute =    5.698 | L6[WIO] S3 C4 M2 P4 - L5[I] M8 R3 C128 - L4[] Q1 N2Y M8Y - L3[O] C2 M2 - L2[W] P64 - L1[I] Q1 - L0[O] Q1
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    5.513
# [  1] Utilization = 0.06 | pJ/Compute =    8.796 | L6[WIO] M8 Q5 - L5[WI] M8 C2 N2 P5 - L4[] Q1 M4Y C4Y - L3[O] M4 C32 Q3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  0] Utilization = 0.06 | pJ/Compute =    8.425 | L6[WIO] N2 C8 M8 P8 - L5[WI] P2 C2 M2 - L4[] Q1 M4Y C4Y - L3[O] C16 M4 P2 S3 R3 - L2[W] P8 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    8.233 | L6[WIO] N2 C8 M8 P8 - L5[WIO] P2 C2 M2 - L4[] Q1 M4Y C4Y - L3[O] C16 M4 P2 S3 R3 - L2[W] P8 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 0.06 | pJ/Compute =    6.086 | L6[WIO] M4 C8 P29 - L5[WI] C8 R3 - L4[] Q1 M16Y - L3[O] M2 N2 C2 S3 - L2[W] Q29 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    6.692
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    7.372
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.06 | pJ/Compute =    7.688 | L6[WIO] P5 M256 - L5[WI] P3 N2 C8 - L4[] Q1 M4Y C4Y - L3[O] C8 - L2[W] Q15 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  3] Utilization = 0.06 | pJ/Compute =    7.480 | L6[WIO] M16 C4 - L5[WIO] C2 M4 Q5 - L4[] Q1 N2Y M8Y - L3[O] M2 C32 P5 - L2[W] P3 Q3 - L1[I] Q1 - L0[O] Q1
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    5.116
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    9.338
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    7.196
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    7.480
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    6.086
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    7.480
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    5.698

# %%
import re
import os
import matplotlib.pyplot as plt
import numpy as np

def extract_numbers_from_lines(file_path, string):
     with open(file_path, 'r') as file:
        for line in file:
            if string in line:
                number_match = re.search(r'\d+\.\d+', line)
                if number_match:
                    return float(number_match.group())
            if string in line:
                number_match = re.search(r'\d+', line)
                if number_match:
                    return int(number_match.group())

def extract_layer_number(filename):
    return int(re.search(r'r(\d+)', filename).group(1))

file_dir1 = 'example_designs/eyeriss_like/outputs_DeepLabv3/'
file_dir2 = 'example_designs/eyeriss_like/outputs_UndilatedDeepLabv3/'
def get_data(string):
    data_dir1 = []
    data_dir2 = []

    dir1 = os.listdir(file_dir1)
    dir2 = os.listdir(file_dir2)

    file_ls1 = sorted(dir1, key=extract_layer_number)
    file_ls2 = sorted(dir2, key=extract_layer_number)

    for file in file_ls1:
        file += '/timeloop-mapper.stats.txt'
        path = os.path.join(file_dir1, file)
        data_dir1.append(extract_numbers_from_lines(path, string))

    for file in file_ls2:
        file += '/timeloop-mapper.stats.txt'
        path = os.path.join(file_dir2, file)
        data_dir2.append(extract_numbers_from_lines(path, string))

    # print(data_dir1)
    # print(data_dir2)
    return data_dir1, data_dir2


# fJ/compute metrics
strings = ["mac                                           ", "psum_spad                                     ",  "weights_spad                                  ", \
           "ifmap_spad                                    ", "shared_glb                                    ", "DRAM                                          ", \
           "Total                                         "]

strings = ["GFLOPs (@1GHz):", "Utilization:", "Cycles:", "Energy:", "EDP(J*cycle):"]
labels = ["GFLOPs (@1GHz)", "Utilization (%)", "Cycles", "Energy (uJ)", "EDP (J*cycle)"]
archs = ["eyeriss_like", "simple_weight_stationary", "simple_output_stationary"]

colors = plt.cm.tab20(np.linspace(0, 1, len(strings) * 2))

def graph_data(data_dir1, data_dir2, string, arch, color1=None, color2=None):
    x_values = np.array(range(len(data_dir1)))
    label = labels[strings.index(string)]
    string = re.sub(r' (?=\s*$)', '', string)
    
    timeframe = 10
    data_dir1 = data_dir1[-timeframe:]
    data_dir2 = data_dir2[-timeframe:]
    x_values = x_values[-timeframe:]

    if color1 is None or color2 is None:
        plt.plot(x_values, np.array(data_dir1), color=color1, label="DL " + arch)
        plt.plot(x_values, np.array(data_dir2), color=color2, label="UDL " + arch)
    else:
        plt.plot(x_values, np.array(data_dir1), label="DL " + arch)
        plt.plot(x_values, np.array(data_dir2), label="UDL " + arch)
    plt.xlabel('Layer')

    if label == "GFLOPs (@1GHz)"
        plt.legend(fontsize="10", loc="upper right")

    if label == "Energy (uJ)" or label == "Cycles":
        plt.yscale('log')
        label = "log " + label
    
    plt.ylabel(label)
        

def loop_graph():
    for i, string in enumerate(strings[0:1]):
        data_dir1, data_dir2 = get_data(string)
        graph_data(data_dir1, data_dir2, string, colors[i], colors[i + len(strings)])
        plt.legend(fontsize="6", loc="upper left")
        plt.show()

def loop_archs_graph():
    for string in strings:
        all_feed1 = []
        all_feed2 = []
        for arch in archs:
            feed1 = []
            feed2 = []
            file_dir1 = f"example_designs/{arch}/outputs_DeepLabv3"
            file_dir2 = f"example_designs/{arch}/outputs_UndilatedDeepLabv3"
            data_dir1 = sorted(os.listdir(file_dir1), key=extract_layer_number)
            data_dir2 = sorted(os.listdir(file_dir2), key=extract_layer_number)
            
            for layer_num in range(len(data_dir1)):
                file_path = file_dir1 + '/' + data_dir1[layer_num] + '/timeloop-mapper.stats.txt'
                feed1.append(extract_numbers_from_lines(file_path, string))
                file_path = file_dir2 + '/' + data_dir2[layer_num] + '/timeloop-mapper.stats.txt'
                feed2.append(extract_numbers_from_lines(file_path, string))
            
            all_feed1.append(feed1)
            all_feed2.append(feed2)
    
        for feed1, feed2, arch in zip(all_feed1, all_feed2, archs):
            graph_data(feed1, feed2, string, arch)
        plt.show()

# %%
# loop_graph()
loop_archs_graph()
